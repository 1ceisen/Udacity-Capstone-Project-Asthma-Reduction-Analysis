# %% [markdown]
# # Impact of Various Factors on Asthma Rates in the United States

# %% [markdown]
# ## Data Model

# %% [markdown]
# #### Import Packages and Load Data

# %%
import pandas as pd
import numpy as np
import math
from pandasql import sqldf

# %%
cdc = pd.read_csv('Data/CDC.csv', converters={'countyfips': str})
emissions = pd.read_csv('Data/Emissions.csv', converters={'state_code': str, 'county_code': str, 'parameter_code':str})
income = pd.read_csv('Data/Income.csv', converters={'GeoFips': str})

# %% [markdown]
# #### Transform Data and Create Master Files

# %% [markdown]
# Create State, County and GeoFips codes needed for aggregations and needed joins.

# %%
# Add 0's to County Code in emissions data set
def county_code(x):
    if len(x) == 1:
        return "00" + str(x)
    elif len(x) ==2:
        return "0" + str(x)
    else:
        return str(x)

# Apply function
emissions['county_code'] = emissions['county_code'].apply(county_code)

# %%
# geoFips for emissions
emissions['GeoFips'] = emissions['state_code'] + emissions['county_code']

# %%
len(emissions['GeoFips'].unique())
# Out:
# 705

# %%
emissions.shape
# Out:
# (10926, 57)

# %% [markdown]
# Add "0" to GeoFips code in income dataset

# %%
# Add 0's to GeoFips Code in income data set
def geofips_code(x):
    if len(x) == 4:
        return "0" + str(x)
    else:
        return str(x)

# Apply function
income['GeoFips'] = income['GeoFips'].apply(geofips_code)

# %% [markdown]
# In this next step aggregate PM25 emissions (Quarterly Mean of Daily Average Mean) by each county.

# %%
# By County

# write query
q = """SELECT GeoFips, 
AVG(arithmetic_mean) as avg_emissions
FROM emissions
WHERE parameter_code = '88101' AND pollutant_standard = 'PM25 Annual 2012'
GROUP BY GeoFips
"""
pysqldf = lambda q: sqldf(q, globals())
county_df_emissions = pysqldf(q)

# %%
county_df_emissions.shape
# Out:
# (625, 2)

# %% [markdown]
# Because numerous County's are missing PM25 emissions data, aggregate PM25 emissions (Quarterly Mean of Daily Average Mean) by each State. These average State PM25 values will be inputted for County's where PM25 emissions are NA.

# %%
# By State

# write query
q = """SELECT state_code, 
AVG(arithmetic_mean) as avg_emissions
FROM emissions
WHERE parameter_code = '88101' AND pollutant_standard = 'PM25 Annual 2012'
GROUP BY state_code
"""
pysqldf = lambda q: sqldf(q, globals())
state_df_emissions = pysqldf(q)

# %%
state_df_emissions.head()
# Out:
#   state_code  avg_emissions
# 0         01       8.540471
# 1         02       9.153661
# 2         04       6.472957
# 3         05       8.653864
# 4         06       7.888009

# %% [markdown]
# Select relevent columns from the CDC data

# %%
cdc_analysis = cdc[['stateabbr', 'statedesc', 'countyname', 'countyfips', 'totalpopulation',
       'access2_adjprev', 'casthma_adjprev', 'csmoking_adjprev']]

# %% [markdown]
# Add State Codes and County Codes to each invidual data set

# %%
def state_code(x):
    if len(x) == 5:
        return str(x[0]) + str(x[1])
    elif len(x) ==4:
        return "0" + str(x[0])
    else:
        return str(x)

# State Codes
cdc_analysis['StateCode'] = cdc_analysis['countyfips'].apply(state_code)
county_df_emissions['StateCode'] = county_df_emissions['GeoFips'].apply(state_code)
income['StateCode'] = income['GeoFips'].apply(state_code)

#County Codes
cdc_analysis['CountyCode'] = cdc_analysis['countyfips'].str[-3:]
county_df_emissions['CountyCode'] = county_df_emissions['GeoFips'].str[-3:]
income['CountyCode'] = income['GeoFips'].str[-3:]
# Out:
# <ipython-input-13-cfd2d2e9d92f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdc_analysis['StateCode'] = cdc_analysis['countyfips'].apply(state_code)
# <ipython-input-13-cfd2d2e9d92f>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdc_analysis['CountyCode'] = cdc_analysis['countyfips'].str[-3:]

# %% [markdown]
# Create master data final

# %%
# write query
q = """SELECT cdc_analysis.*, 
county_df_emissions.avg_emissions as county_emissions,
income.'2019' as per_capita_income,
state_df_emissions.avg_emissions as state_emissions
FROM cdc_analysis
LEFT JOIN county_df_emissions on cdc_analysis.countyfips = county_df_emissions.GeoFips
LEFT JOIN income on cdc_analysis.countyfips = income.GeoFips
LEFT JOIN state_df_emissions on cdc_analysis.StateCode = state_df_emissions.state_code

"""
pysqldf = lambda q: sqldf(q, globals())
master_df = pysqldf(q)

# %%
# Fill county's with NA PM25 emissions data with average State PM25 emissions
master_df['county_emissions'] = master_df['county_emissions'].fillna(master_df['state_emissions'])

# %%
master_df.shape
# Out:
# (3142, 13)

# %% [markdown]
# #### Data diagnostics

# %% [markdown]
# Check for missing values in columns of interest

# %%
# Explanatory Variables
print(np.sum(master_df.county_emissions.isnull()))
print(np.sum(master_df.csmoking_adjprev.isnull()))
print(np.sum(master_df.access2_adjprev.isnull()))
print(np.sum(master_df.per_capita_income.isnull()))
# Out:
# 0
# 21
# 21
# 53

# %%
# Dependent Variable
print(np.sum(master_df.casthma_adjprev.isnull()))
# Out:
# 21

# %%
# print rows that are NA
master_df[master_df.access2_adjprev.isna()]
# Out:
#      stateabbr   statedesc  countyname countyfips  totalpopulation  \
# 199         NJ  New Jersey       Union      34039           556341
# 205         NJ  New Jersey  Cumberland      34011           149527
# 221         NJ  New Jersey       Ocean      34029           607186
# 224         NJ  New Jersey       Essex      34013           798975
# 322         NJ  New Jersey      Hudson      34017           672391
# 327         NJ  New Jersey     Passaic      34031           501826
# 402         NJ  New Jersey      Sussex      34037           140488
# 553         NJ  New Jersey    Cape May      34009            92039
# 815         NJ  New Jersey   Hunterdon      34019           124371
# 1008        NJ  New Jersey      Morris      34027           491845
# 1091        NJ  New Jersey      Warren      34041           105267
# 1227        NJ  New Jersey    Somerset      34035           328934
# 1267        NJ  New Jersey  Burlington      34005           445349
# 1573        NJ  New Jersey      Mercer      34021           367430
# 1644        NJ  New Jersey    Monmouth      34025           618795
# 2025        NJ  New Jersey      Bergen      34003           932202
# 2276        NJ  New Jersey       Salem      34033            62385
# 2307        NJ  New Jersey   Middlesex      34023           825062
# 2528        NJ  New Jersey  Gloucester      34015           291636
# 2688        NJ  New Jersey      Camden      34007           506471
# 2768        NJ  New Jersey    Atlantic      34001           263670
#
#       access2_adjprev  casthma_adjprev  csmoking_adjprev StateCode CountyCode  \
# 199               NaN              NaN               NaN        34        039
# 205               NaN              NaN               NaN        34        011
# 221               NaN              NaN               NaN        34        029
# 224               NaN              NaN               NaN        34        013
# 322               NaN              NaN               NaN        34        017
# 327               NaN              NaN               NaN        34        031
# 402               NaN              NaN               NaN        34        037
# 553               NaN              NaN               NaN        34        009
# 815               NaN              NaN               NaN        34        019
# 1008              NaN              NaN               NaN        34        027
# 1091              NaN              NaN               NaN        34        041
# 1227              NaN              NaN               NaN        34        035
# 1267              NaN              NaN               NaN        34        005
# 1573              NaN              NaN               NaN        34        021
# 1644              NaN              NaN               NaN        34        025
# 2025              NaN              NaN               NaN        34        003
# 2276              NaN              NaN               NaN        34        033
# 2307              NaN              NaN               NaN        34        023
# 2528              NaN              NaN               NaN        34        015
# 2688              NaN              NaN               NaN        34        007
# 2768              NaN              NaN               NaN        34        001
#
#       county_emissions  per_capita_income  state_emissions
# 199           8.583793            68867.0          7.86686
# 205           7.798476            41327.0          7.86686
# 221           6.259420            53517.0          7.86686
# 224           8.408746            65927.0          7.86686
# 322           8.140014            67570.0          7.86686
# 327           7.673451            51203.0          7.86686
# 402           7.866860            64284.0          7.86686
# 553           7.866860            63203.0          7.86686
# 815           7.785955            91946.0          7.86686
# 1008          5.553097            99140.0          7.86686
# 1091          7.129696            56956.0          7.86686
# 1227          7.866860           110466.0          7.86686
# 1267          7.866860            63528.0          7.86686
# 1573          7.587980            70675.0          7.86686
# 1644          7.866860            82270.0          7.86686
# 2025          9.052121            88241.0          7.86686
# 2276          7.866860            50597.0          7.86686
# 2307          7.329149            62665.0          7.86686
# 2528          7.138983            56853.0          7.86686
# 2688          8.876943            54958.0          7.86686
# 2768          6.509320            51247.0          7.86686

# %% [markdown]
# To fill in missing values we will aggregate the missing features by state and input those values at the county level

# %%
# write query
q = """SELECT statedesc, 
StateCode,
AVG(csmoking_adjprev) as csmoking_adjprev_state,
AVG(access2_adjprev) as access2_adjprev_state,
AVG(per_capita_income) as per_capita_income_state,
AVG(casthma_adjprev) as casthma_adjprev_state
FROM master_df
GROUP BY statedesc
"""
pysqldf = lambda q: sqldf(q, globals())
state_agg = pysqldf(q)

# %% [markdown]
# Join state_agg dataframe onto master dataframe

# %%
# write query
q = """SELECT master_df.*,
state_agg.csmoking_adjprev_state,
state_agg.access2_adjprev_state,
state_agg.per_capita_income_state,
state_agg.casthma_adjprev_state
FROM master_df
LEFT JOIN state_agg on master_df.StateCode = state_agg.StateCode
"""
pysqldf = lambda q: sqldf(q, globals())
master_df = pysqldf(q)

# %%
master_df.head()
# Out:
#   stateabbr       statedesc  countyname countyfips  totalpopulation  \
# 0        NC  North Carolina      Warren      37185            19731
# 1        SC  South Carolina       Aiken      45003           170872
# 2        SC  South Carolina     Calhoun      45017            14553
# 3        SC  South Carolina  Darlington      45031            66618
# 4        SC  South Carolina    Florence      45041           138293
#
#    access2_adjprev  casthma_adjprev  csmoking_adjprev StateCode CountyCode  \
# 0             23.3             10.9              24.6        37        185
# 1             19.7              9.9              18.3        45        003
# 2             20.0             10.3              20.0        45        017
# 3             21.0             10.9              22.9        45        031
# 4             19.8             10.3              20.4        45        041
#
#    county_emissions  per_capita_income  state_emissions  \
# 0          7.565971            30317.0         7.565971
# 1          7.449686            44503.0         7.449686
# 2          7.449686            41620.0         7.449686
# 3          7.449686            39085.0         7.449686
# 4          7.714407            43759.0         7.449686
#
#    csmoking_adjprev_state  access2_adjprev_state  per_capita_income_state  \
# 0                21.27500              20.399000             41171.100000
# 1                21.21087              21.095652             39970.282609
# 2                21.21087              21.095652             39970.282609
# 3                21.21087              21.095652             39970.282609
# 4                21.21087              21.095652             39970.282609
#
#    casthma_adjprev_state
# 0                  9.768
# 1                 10.250
# 2                 10.250
# 3                 10.250
# 4                 10.250

# %% [markdown]
# Input missing values

# %%
# Fill county's with NA average smoking rates data with average State  rates 
master_df['csmoking_adjprev'] = master_df['csmoking_adjprev'].fillna(master_df['csmoking_adjprev_state'])

# Fill county's with NA average accessibility to health care data with average State rates 
master_df['access2_adjprev'] = master_df['access2_adjprev'].fillna(master_df['access2_adjprev_state'])

# Fill county's with NA per capita income data with average State rates 
master_df['per_capita_income'] = master_df['per_capita_income'].fillna(master_df['per_capita_income_state'])

# Fill county's with NA average asthma rates data with average State rates 
master_df['casthma_adjprev'] = master_df['casthma_adjprev'].fillna(master_df['casthma_adjprev_state'])

# %% [markdown]
# Check for missing values again

# %%
# Explanatory Variables
print(np.sum(master_df.county_emissions.isnull()))
print(np.sum(master_df.csmoking_adjprev.isnull()))
print(np.sum(master_df.access2_adjprev.isnull()))
print(np.sum(master_df.per_capita_income.isnull()))
# Out:
# 0
# 21
# 21
# 0

# %%
# Dependent Variable
print(np.sum(master_df.casthma_adjprev.isnull()))
# Out:
# 21

# %%
# print rows that are NA
master_df[master_df.access2_adjprev.isna()]
# Out:
#      stateabbr   statedesc  countyname countyfips  totalpopulation  \
# 199         NJ  New Jersey       Union      34039           556341
# 205         NJ  New Jersey  Cumberland      34011           149527
# 221         NJ  New Jersey       Ocean      34029           607186
# 224         NJ  New Jersey       Essex      34013           798975
# 322         NJ  New Jersey      Hudson      34017           672391
# 327         NJ  New Jersey     Passaic      34031           501826
# 402         NJ  New Jersey      Sussex      34037           140488
# 553         NJ  New Jersey    Cape May      34009            92039
# 815         NJ  New Jersey   Hunterdon      34019           124371
# 1008        NJ  New Jersey      Morris      34027           491845
# 1091        NJ  New Jersey      Warren      34041           105267
# 1227        NJ  New Jersey    Somerset      34035           328934
# 1267        NJ  New Jersey  Burlington      34005           445349
# 1573        NJ  New Jersey      Mercer      34021           367430
# 1644        NJ  New Jersey    Monmouth      34025           618795
# 2025        NJ  New Jersey      Bergen      34003           932202
# 2276        NJ  New Jersey       Salem      34033            62385
# 2307        NJ  New Jersey   Middlesex      34023           825062
# 2528        NJ  New Jersey  Gloucester      34015           291636
# 2688        NJ  New Jersey      Camden      34007           506471
# 2768        NJ  New Jersey    Atlantic      34001           263670
#
#       access2_adjprev  casthma_adjprev  csmoking_adjprev StateCode CountyCode  \
# 199               NaN              NaN               NaN        34        039
# 205               NaN              NaN               NaN        34        011
# 221               NaN              NaN               NaN        34        029
# 224               NaN              NaN               NaN        34        013
# 322               NaN              NaN               NaN        34        017
# 327               NaN              NaN               NaN        34        031
# 402               NaN              NaN               NaN        34        037
# 553               NaN              NaN               NaN        34        009
# 815               NaN              NaN               NaN        34        019
# 1008              NaN              NaN               NaN        34        027
# 1091              NaN              NaN               NaN        34        041
# 1227              NaN              NaN               NaN        34        035
# 1267              NaN              NaN               NaN        34        005
# 1573              NaN              NaN               NaN        34        021
# 1644              NaN              NaN               NaN        34        025
# 2025              NaN              NaN               NaN        34        003
# 2276              NaN              NaN               NaN        34        033
# 2307              NaN              NaN               NaN        34        023
# 2528              NaN              NaN               NaN        34        015
# 2688              NaN              NaN               NaN        34        007
# 2768              NaN              NaN               NaN        34        001
#
#       county_emissions  per_capita_income  state_emissions  \
# 199           8.583793            68867.0          7.86686
# 205           7.798476            41327.0          7.86686
# 221           6.259420            53517.0          7.86686
# 224           8.408746            65927.0          7.86686
# 322           8.140014            67570.0          7.86686
# 327           7.673451            51203.0          7.86686
# 402           7.866860            64284.0          7.86686
# 553           7.866860            63203.0          7.86686
# 815           7.785955            91946.0          7.86686
# 1008          5.553097            99140.0          7.86686
# 1091          7.129696            56956.0          7.86686
# 1227          7.866860           110466.0          7.86686
# 1267          7.866860            63528.0          7.86686
# 1573          7.587980            70675.0          7.86686
# 1644          7.866860            82270.0          7.86686
# 2025          9.052121            88241.0          7.86686
# 2276          7.866860            50597.0          7.86686
# 2307          7.329149            62665.0          7.86686
# 2528          7.138983            56853.0          7.86686
# 2688          8.876943            54958.0          7.86686
# 2768          6.509320            51247.0          7.86686
#
#       csmoking_adjprev_state  access2_adjprev_state  per_capita_income_state  \
# 199                      NaN                    NaN             67401.904762
# 205                      NaN                    NaN             67401.904762
# 221                      NaN                    NaN             67401.904762
# 224                      NaN                    NaN             67401.904762
# 322                      NaN                    NaN             67401.904762
# 327                      NaN                    NaN             67401.904762
# 402                      NaN                    NaN             67401.904762
# 553                      NaN                    NaN             67401.904762
# 815                      NaN                    NaN             67401.904762
# 1008                     NaN                    NaN             67401.904762
# 1091                     NaN                    NaN             67401.904762
# 1227                     NaN                    NaN             67401.904762
# 1267                     NaN                    NaN             67401.904762
# 1573                     NaN                    NaN             67401.904762
# 1644                     NaN                    NaN             67401.904762
# 2025                     NaN                    NaN             67401.904762
# 2276                     NaN                    NaN             67401.904762
# 2307                     NaN                    NaN             67401.904762
# 2528                     NaN                    NaN             67401.904762
# 2688                     NaN                    NaN             67401.904762
# 2768                     NaN                    NaN             67401.904762
#
#       casthma_adjprev_state
# 199                     NaN
# 205                     NaN
# 221                     NaN
# 224                     NaN
# 322                     NaN
# 327                     NaN
# 402                     NaN
# 553                     NaN
# 815                     NaN
# 1008                    NaN
# 1091                    NaN
# 1227                    NaN
# 1267                    NaN
# 1573                    NaN
# 1644                    NaN
# 2025                    NaN
# 2276                    NaN
# 2307                    NaN
# 2528                    NaN
# 2688                    NaN
# 2768                    NaN

# %% [markdown]
# Appears New jersey has no CDC data for any fields. Because of this, lets exclude New Jersey from this analysis and focus on all other states (plus District of Columbia).

# %%
master_df = master_df[master_df.StateCode != '34']

# %%
dff = master_df.groupby(['statedesc']).agg({'totalpopulation':'sum'}).reset_index()

# %%
dff.dtypes
# Out:
# statedesc          object
# totalpopulation     int64
# dtype: object

# %% [markdown]
# ## Regression Model

# %% [markdown]
# #### OLS Model

# %% [markdown]
# Import needed packages

# %%
import statsmodels.formula.api as sm
from scipy.stats import pearsonr
from statsmodels.compat import lzip
import statsmodels.stats.api as sms

# %% [markdown]
# Summary statistics

# %%
master_df.describe()
# Out:
#        totalpopulation  access2_adjprev  casthma_adjprev  csmoking_adjprev  \
# count     3.121000e+03      3121.000000      3121.000000       3121.000000
# mean      1.023253e+05        18.373662         9.719449         20.397661
# std       3.328885e+05         6.839567         0.974270          4.188090
# min       8.600000e+01         7.900000         7.200000          6.500000
# 25%       1.080300e+04        13.400000         9.000000         17.600000
# 50%       2.547300e+04        16.600000         9.800000         20.100000
# 75%       6.682400e+04        21.200000        10.400000         23.200000
# max       1.003911e+07        56.600000        14.300000         43.000000
#
#        county_emissions  per_capita_income  state_emissions  \
# count       3121.000000        3121.000000      3121.000000
# mean           7.602723       45347.496808         7.667687
# std            1.290314       12617.058481         1.155014
# min            0.915000       18944.000000         2.597847
# 25%            7.014711       37826.000000         7.062724
# 50%            7.883339       43196.000000         8.075398
# 75%            8.575984       49652.000000         8.575984
# max           13.098077      222893.000000         9.153661
#
#        csmoking_adjprev_state  access2_adjprev_state  per_capita_income_state  \
# count             3121.000000            3121.000000              3121.000000
# mean                20.397661              18.373662             45347.496808
# std                  3.046591               5.910140              6186.590900
# min                 11.137931              10.040000             36175.670732
# 25%                 18.418110              13.420482             39576.431579
# 50%                 19.893750              17.773438             45259.794118
# 75%                 22.454717              20.940000             48728.282051
# max                 26.709167              32.727165             80819.000000
#
#        casthma_adjprev_state
# count            3121.000000
# mean                9.719449
# std                 0.729419
# min                 8.238710
# 25%                 9.103448
# 50%                 9.872932
# 75%                10.312174
# max                11.132727

# %% [markdown]
# Produce correlation matrix to examine variables that might be highly correlated to avoid multi-colinearity

# %%
rho = master_df.corr()
rho
# Out:
#                          totalpopulation  access2_adjprev  casthma_adjprev  \
# totalpopulation                 1.000000        -0.007385        -0.157270
# access2_adjprev                -0.007385         1.000000        -0.140265
# casthma_adjprev                -0.157270        -0.140265         1.000000
# csmoking_adjprev               -0.278976         0.100791         0.703402
# county_emissions                0.040587         0.284465         0.156154
# per_capita_income               0.247884        -0.263310        -0.447619
# state_emissions                -0.008185         0.285723         0.178703
# csmoking_adjprev_state         -0.133334        -0.035354         0.435854
# access2_adjprev_state           0.007258         0.864110        -0.258204
# per_capita_income_state         0.128635        -0.227580        -0.354687
# casthma_adjprev_state          -0.032417        -0.298012         0.748683
#
#                          csmoking_adjprev  county_emissions  \
# totalpopulation                 -0.278976          0.040587
# access2_adjprev                  0.100791          0.284465
# casthma_adjprev                  0.703402          0.156154
# csmoking_adjprev                 1.000000          0.290825
# county_emissions                 0.290825          1.000000
# per_capita_income               -0.595899         -0.230342
# state_emissions                  0.313997          0.892766
# csmoking_adjprev_state           0.727442          0.400025
# access2_adjprev_state           -0.029763          0.309638
# per_capita_income_state         -0.502624         -0.457157
# casthma_adjprev_state            0.423488          0.209228
#
#                          per_capita_income  state_emissions  \
# totalpopulation                   0.247884        -0.008185
# access2_adjprev                  -0.263310         0.285723
# casthma_adjprev                  -0.447619         0.178703
# csmoking_adjprev                 -0.595899         0.313997
# county_emissions                 -0.230342         0.892766
# per_capita_income                 1.000000        -0.241577
# state_emissions                  -0.241577         1.000000
# csmoking_adjprev_state           -0.338796         0.431646
# access2_adjprev_state            -0.129139         0.330655
# per_capita_income_state           0.490335        -0.492678
# casthma_adjprev_state            -0.232296         0.238690
#
#                          csmoking_adjprev_state  access2_adjprev_state  \
# totalpopulation                       -0.133334               0.007258
# access2_adjprev                       -0.035354               0.864110
# casthma_adjprev                        0.435854              -0.258204
# csmoking_adjprev                       0.727442              -0.029763
# county_emissions                       0.400025               0.309638
# per_capita_income                     -0.338796              -0.129139
# state_emissions                        0.431646               0.330655
# csmoking_adjprev_state                 1.000000              -0.040914
# access2_adjprev_state                 -0.040914               1.000000
# per_capita_income_state               -0.690948              -0.263369
# casthma_adjprev_state                  0.582161              -0.344878
#
#                          per_capita_income_state  casthma_adjprev_state
# totalpopulation                         0.128635              -0.032417
# access2_adjprev                        -0.227580              -0.298012
# casthma_adjprev                        -0.354687               0.748683
# csmoking_adjprev                       -0.502624               0.423488
# county_emissions                       -0.457157               0.209228
# per_capita_income                       0.490335              -0.232296
# state_emissions                        -0.492678               0.238690
# csmoking_adjprev_state                 -0.690948               0.582161
# access2_adjprev_state                  -0.263369              -0.344878
# per_capita_income_state                 1.000000              -0.473749
# casthma_adjprev_state                  -0.473749               1.000000

# %% [markdown]
# In this next step, regular OLS will be conducted. To test for random effects a Breusch- Pagan Lagrange Multiplier Test will be conducted. Whereby the following hypothesis test will be performed:
#
# 𝑯𝟎: 𝑽𝒂𝒓𝒊𝒂𝒏𝒄𝒆 𝒂𝒄𝒓𝒐𝒔𝒔 𝒐𝒃𝒔𝒆𝒓𝒗𝒂𝒕𝒊𝒐𝒏𝒔 𝒊𝒔 𝒆𝒒𝒖𝒂𝒍 𝒕𝒐 𝒛𝒆𝒓𝒐 (𝑶𝑳𝑺 𝒊𝒔 𝒂𝒑𝒑𝒓𝒐𝒑𝒓𝒊𝒂𝒕𝒆)
#
# 𝑯𝟏: 𝑽𝒂𝒓𝒊𝒂𝒏𝒄𝒆 𝒂𝒄𝒓𝒐𝒔𝒔 𝒐𝒃𝒔𝒆𝒓𝒗𝒂𝒕𝒊𝒐𝒏𝒔 𝒊𝒔 𝒏𝒐𝒕 𝒆𝒒𝒖𝒂𝒍 𝒕𝒐 𝒛𝒆𝒓𝒐 (𝑹𝒂𝒏𝒅𝒐𝒎 𝑬𝒇𝒇𝒆𝒄𝒕𝒔 𝒊𝒔 𝒂𝒑𝒑𝒓𝒐𝒑𝒓𝒊𝒂𝒕𝒆)

# %%
normal_ols = sm.ols(formula='''casthma_adjprev ~ np.log(county_emissions) + csmoking_adjprev +
                    access2_adjprev + np.log(per_capita_income)''',
                          data=master_df).fit()
print(normal_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        casthma_adjprev   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.553
# Method:                 Least Squares   F-statistic:                     966.3
# Date:                Sun, 09 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:37:48   Log-Likelihood:                -3087.8
# No. Observations:                3121   AIC:                             6186.
# Df Residuals:                    3116   BIC:                             6216.
# Df Model:                           4
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    14.8652      0.829     17.934      0.000      13.240      16.490
# np.log(county_emissions)      0.0141      0.062      0.225      0.822      -0.108       0.136
# csmoking_adjprev              0.1439      0.004     37.566      0.000       0.136       0.151
# access2_adjprev              -0.0365      0.002    -19.522      0.000      -0.040      -0.033
# np.log(per_capita_income)    -0.6956      0.071     -9.826      0.000      -0.834      -0.557
# ==============================================================================
# Omnibus:                       74.860   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.852
# Skew:                           0.380   Prob(JB):                     4.57e-18
# Kurtosis:                       3.192   Cond. No.                     2.14e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#perform Bresuch-Pagan test
names = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(normal_ols.resid, normal_ols.model.exog)

lzip(names, test)
# Out:
# [('Lagrange multiplier statistic', 124.35394974713637),
#  ('p-value', 6.272515418886365e-26),
#  ('f-value', 32.3267163450435),
#  ('f p-value', 1.9418323653136825e-26)]

# %% [markdown]
# We can reject the null hypothesis and conclude that Random Effects are present. Therefore a Fixed Effects model with States as dummy variables is appropriate. In this previous regression model the coefficient for county emissions was not significant. Since we are running a Fixed Effects model to account for state specific effects, perhaps it is more appropriate to examine the impact of state emissions on asthma rates. Because emissions are bound by no geographical location, this might be a more appropriate approach. Addiitonally, State governments might have more authority to impliment measures to reduce overall PM25 emission rates.

# %% [markdown]
# #### Fixed Effects

# %%
fixed_model = sm.ols(formula='''casthma_adjprev ~ np.log(state_emissions) + csmoking_adjprev +
                    access2_adjprev + np.log(per_capita_income) + C(statedesc)''',
                          data=master_df).fit()
print(fixed_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        casthma_adjprev   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     433.0
# Date:                Sun, 09 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:37:50   Log-Likelihood:                -1036.8
# No. Observations:                3121   AIC:                             2180.
# Df Residuals:                    3068   BIC:                             2500.
# Df Model:                          52
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                3.1821      0.305     10.429      0.000       2.584       3.780
# C(statedesc)[T.Alaska]                  -0.3216      0.079     -4.081      0.000      -0.476      -0.167
# C(statedesc)[T.Arizona]                  1.0488      0.095     11.025      0.000       0.862       1.235
# C(statedesc)[T.Arkansas]                -0.1222      0.058     -2.112      0.035      -0.236      -0.009
# C(statedesc)[T.California]               0.6570      0.062     10.630      0.000       0.536       0.778
# C(statedesc)[T.Colorado]                 0.5410      0.058      9.401      0.000       0.428       0.654
# C(statedesc)[T.Connecticut]              1.2186      0.127      9.566      0.000       0.969       1.468
# C(statedesc)[T.Delaware]                 0.8435      0.200      4.218      0.000       0.451       1.236
# C(statedesc)[T.District of Columbia]     1.4245      0.343      4.148      0.000       0.751       2.098
# C(statedesc)[T.Florida]                 -0.8604      0.060    -14.297      0.000      -0.978      -0.742
# C(statedesc)[T.Georgia]                 -0.2363      0.053     -4.455      0.000      -0.340      -0.132
# C(statedesc)[T.Hawaii]                   0.8342      0.176      4.751      0.000       0.490       1.178
# C(statedesc)[T.Idaho]                    0.8116      0.067     12.025      0.000       0.679       0.944
# C(statedesc)[T.Illinois]                -0.2819      0.057     -4.953      0.000      -0.393      -0.170
# C(statedesc)[T.Indiana]                 -0.1595      0.057     -2.811      0.005      -0.271      -0.048
# C(statedesc)[T.Iowa]                    -0.9959      0.053    -18.824      0.000      -1.100      -0.892
# C(statedesc)[T.Kansas]                   0.1877      0.052      3.644      0.000       0.087       0.289
# C(statedesc)[T.Kentucky]                -0.6428      0.054    -11.940      0.000      -0.748      -0.537
# C(statedesc)[T.Louisiana]               -0.5620      0.059     -9.526      0.000      -0.678      -0.446
# C(statedesc)[T.Maine]                    1.6130      0.101     16.013      0.000       1.416       1.811
# C(statedesc)[T.Maryland]                 0.3737      0.080      4.673      0.000       0.217       0.531
# C(statedesc)[T.Massachusetts]            1.2087      0.103     11.678      0.000       1.006       1.412
# C(statedesc)[T.Michigan]                 0.8049      0.055     14.655      0.000       0.697       0.913
# C(statedesc)[T.Minnesota]               -0.3095      0.054     -5.686      0.000      -0.416      -0.203
# C(statedesc)[T.Mississippi]              0.5729      0.058      9.911      0.000       0.460       0.686
# C(statedesc)[T.Missouri]                -0.1519      0.051     -2.954      0.003      -0.253      -0.051
# C(statedesc)[T.Montana]                  0.5669      0.064      8.879      0.000       0.442       0.692
# C(statedesc)[T.Nebraska]                -0.7658      0.054    -14.183      0.000      -0.872      -0.660
# C(statedesc)[T.Nevada]                  -0.0166      0.097     -0.172      0.864      -0.206       0.173
# C(statedesc)[T.New Hampshire]            1.3836      0.127     10.864      0.000       1.134       1.633
# C(statedesc)[T.New Mexico]               0.1517      0.069      2.186      0.029       0.016       0.288
# C(statedesc)[T.New York]                 0.7947      0.059     13.470      0.000       0.679       0.910
# C(statedesc)[T.North Carolina]          -0.0947      0.051     -1.855      0.064      -0.195       0.005
# C(statedesc)[T.North Dakota]            -0.4911      0.082     -5.979      0.000      -0.652      -0.330
# C(statedesc)[T.Ohio]                    -0.1695      0.057     -2.968      0.003      -0.281      -0.058
# C(statedesc)[T.Oklahoma]                 0.5159      0.056      9.282      0.000       0.407       0.625
# C(statedesc)[T.Oregon]                   1.2725      0.069     18.476      0.000       1.137       1.408
# C(statedesc)[T.Pennsylvania]             0.2632      0.060      4.368      0.000       0.145       0.381
# C(statedesc)[T.Rhode Island]             1.8285      0.159     11.494      0.000       1.517       2.140
# C(statedesc)[T.South Carolina]           0.4203      0.063      6.702      0.000       0.297       0.543
# C(statedesc)[T.South Dakota]            -0.5250      0.071     -7.421      0.000      -0.664      -0.386
# C(statedesc)[T.Tennessee]               -0.3623      0.053     -6.830      0.000      -0.466      -0.258
# C(statedesc)[T.Texas]                   -0.7001      0.057    -12.347      0.000      -0.811      -0.589
# C(statedesc)[T.Utah]                     2.0982      0.072     28.947      0.000       1.956       2.240
# C(statedesc)[T.Vermont]                  1.1994      0.102     11.816      0.000       1.000       1.398
# C(statedesc)[T.Virginia]                 0.3536      0.048      7.343      0.000       0.259       0.448
# C(statedesc)[T.Washington]               1.3409      0.066     20.308      0.000       1.211       1.470
# C(statedesc)[T.West Virginia]            0.2840      0.062      4.569      0.000       0.162       0.406
# C(statedesc)[T.Wisconsin]                0.3093      0.056      5.568      0.000       0.200       0.418
# C(statedesc)[T.Wyoming]                  0.1680      0.115      1.459      0.145      -0.058       0.394
# np.log(state_emissions)                  0.4377      0.114      3.831      0.000       0.214       0.662
# csmoking_adjprev                         0.2034      0.003     70.673      0.000       0.198       0.209
# access2_adjprev                         -0.0118      0.002     -6.004      0.000      -0.016      -0.008
# np.log(per_capita_income)                0.1609      0.043      3.718      0.000       0.076       0.246
# ==============================================================================
# Omnibus:                      328.371   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              897.650
# Skew:                           0.579   Prob(JB):                    1.20e-195
# Kurtosis:                       5.359   Cond. No.                     1.30e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.66e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Obtain regression coefficients

# %%
# State Emissions
state_emissions_coef = pd.read_html(fixed_model.summary2().as_html())[1][1][51]
state_emissions_coef = f = float(state_emissions_coef)
print("State emissions regression coefficient = {}.".format(state_emissions_coef))

# Smoking Rates
csmoking_adjprev_coef = pd.read_html(fixed_model.summary2().as_html())[1][1][52]
csmoking_adjprev_coef = f = float(csmoking_adjprev_coef)
print("Smoking rates regression coefficient = {}.".format(csmoking_adjprev_coef))

# No health care accessibility
access2_adjprev_coef = pd.read_html(fixed_model.summary2().as_html())[1][1][53]
access2_adjprev_coef = f = float(access2_adjprev_coef)
print("No health care accessibility regression coefficient = {}.".format(access2_adjprev_coef))
# Out:
# State emissions regression coefficient = 0.4377.
# Smoking rates regression coefficient = 0.2034.
# No health care accessibility regression coefficient = -0.0118.

# %% [markdown]
# ## Analysis of Findings

# %% [markdown]
# Now that we have found the relationship between various factors and their impact on Asthma rates, lets examine the societal benefits of a 1% reduction in state emission and smoking rates, while examing the impacts of a 1% increase in health care accessibility. based on the following article, the societal cost of asthma per person is approximately $3,100 USD per year (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5219738/). Reducing overall asthma rates would have a great economic benefit for many households. Because asthma has no permanent cure our focus will be on prevention of future asthma rates, with a focus on how reductions today could impact the population (age 19-64) by 2030 based on birth rate data from the United States Census Bureau (https://www.census.gov/library/publications/2020/demo/p25-1144.html & https://www.kff.org/other/state-indicator/distribution-by-age/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)

# %% [markdown]
# The 2030 projected United States population is 355.1 million, with approximately 60% of the population falling within the age range of 19-64. Noting that the 2020 popultion is 332.6 we can assess the growth rate over this approximate period. Using this information lets find the current (2019) population and examine the growth rate, which can be applied uniformly to each respective county

# %%
growth_rate = (355.1-332.6) / 332.6
growth_rate_percent = "{0:.2f}%". format(growth_rate*100)
print("The expected population growth between 2020 and 2030 for the United States is = {}.".format(growth_rate_percent))
# Out:
# The expected population growth between 2020 and 2030 for the United States is = 6.76%.

# %%
# Apply growth rate to population within ragne of analysis (19-64)
master_df['net_growth_19to64'] = (((master_df['totalpopulation']*0.6) * (1 + growth_rate)) - (master_df['totalpopulation']*0.6))
master_df['net_growth_19to64'] = master_df['net_growth_19to64'].astype(int)

# %% [markdown]
# Impact of a 1% reduction in State emissions

# %%
# Impact of reduced emissions

# Set percentage impact
x = 1

# Estimated number of reduced asthma cases by county
reduced_emissions = (master_df['net_growth_19to64'] * (master_df['casthma_adjprev']/100)) - (master_df['net_growth_19to64'] * ((master_df['casthma_adjprev'] - (state_emissions_coef*x))/100))
# Convert to int
reduced_emissions = reduced_emissions.astype(int)
# Total impact
reduced_emissions = np.sum(reduced_emissions)
# Apply monetary societal benefit
reduced_emissions_monetary =  reduced_emissions * 3100
# Convert to int
reduced_emissions_monetary = reduced_emissions_monetary.astype(int)
# Convert to monetary object
reduced_emissions_monetary = "${0:,.0f}". format(reduced_emissions_monetary)

string = "A %s percent reduction in State emissions is associated with an estimated %s reduced asthma cases which amounts to %s in total societal beneftis" % (x, reduced_emissions, reduced_emissions_monetary)
print(string)
# Out:
# A 1 percent reduction in State emissions is associated with an estimated 55182 reduced asthma cases which amounts to $171,064,200 in total societal beneftis

# %% [markdown]
# Impact of a 1% reduction in Smoking Rates

# %%
# Impact of reduced smoking rates

# Set percentage impact
x = 1

# Estimated number of reduced asthma cases by county
reduced_smoking = (master_df['net_growth_19to64'] * (master_df['casthma_adjprev']/100)) - (master_df['net_growth_19to64'] * ((master_df['casthma_adjprev'] - (csmoking_adjprev_coef*x))/100))
# Convert to int
reduced_smoking = reduced_smoking.astype(int)
# Total impact
reduced_smoking = np.sum(reduced_smoking)
# Apply monetary societal benefit
reduced_smoking_monetary = reduced_smoking * 3100
# Convert to int
reduced_smoking_monetary = reduced_smoking_monetary.astype(int)
# Convert to monetary object
reduced_smoking_monetary = "${0:,.0f}". format(reduced_smoking_monetary)

string = "A %s percent reduction in County smoking rates is associated with an estimated %s reduced asthma cases which amounts to %s in total societal beneftis" % (x, reduced_smoking, reduced_smoking_monetary)
print(string)
# Out:
# A 1 percent reduction in County smoking rates is associated with an estimated 24863 reduced asthma cases which amounts to $77,075,300 in total societal beneftis

# %% [markdown]
# Impact of 1% increase in Health Care Accessibility

# %%
# Impact of increased health care accessibility

# Set percentage impact
x = 1

# Estimated number of reduced asthma cases by county
increased_access = (master_df['net_growth_19to64'] * (master_df['casthma_adjprev']/100)) - (master_df['net_growth_19to64'] * ((master_df['casthma_adjprev'] - (-access2_adjprev_coef*x))/100))
# Convert to int
increased_access = increased_access.astype(int)
# Total impact
increased_access = np.sum(increased_access)
# Apply monetary societal benefit
increased_access_monetary = increased_access * 3100
# Convert to int
increased_access_monetary = increased_access_monetary.astype(int)
# Convert to monetary object
increased_access_monetary = "${0:,.0f}". format(increased_access_monetary)

string = "A %s percent increase in health care accessibility, by County, is associated with an estimated %s reduced asthma cases which amounts to %s in total societal beneftis" % (x, increased_access, increased_access_monetary)
print(string)
# Out:
# A 1 percent increase in health care accessibility, by County, will result in an estimated 891 reduction in asthma cases which amounts to $2,762,100 in total societal beneftis

# %% [markdown]
# ## Extension of Model

# %% [markdown]
# Many great insights have come from this analysis. However the interactivity of this analysis is quite limited. For further extension into Analysis of Findings the data and model from this analysis will be utilized as Plotly objects in developing a Dash web interface.

# %%
# Export Master Data
master_df.to_csv("Data/Master_Data.csv", index=False)
